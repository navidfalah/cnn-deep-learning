# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim

import matplotlib.pyplot as plt
import numpy as np

# %%
import torch

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
### loading the datasets and make it in a dataloader

transform_train = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

transform_test = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

batch_size = 64

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Assuming the dataset sizes and batch size
total_train_data = len(trainloader.dataset)  # This gives the total number of training images
total_test_data = len(testloader.dataset)

print(f"Total training data: {total_train_data}")
print(f"Total testing data: {total_test_data}")
# Out:
# Total training data: 50000
# Total testing data: 10000

# %%
### alex net architectures

class AlexNet(nn.Module):
    def __init__(self, num_classes=100):
        super(AlexNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.avgpool = nn.AdaptiveAvgPool2d((6, 6))
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Linear(4096, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x
alexnet = AlexNet().cuda()

# %%
vgg16 = torchvision.models.vgg16(pretrained=True)
vgg16.classifier[6] = nn.Linear(4096, 100)
vgg16.cuda()
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=100, bias=True)
#   )
# )

# %%
resnet50 = torchvision.models.resnet50(pretrained=True)
resnet50.fc = nn.Linear(resnet50.fc.in_features, 100)
resnet50.cuda()
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=100, bias=True)
# )

# %%
googlenet = torchvision.models.googlenet(pretrained=True)
googlenet.fc = nn.Linear(googlenet.fc.in_features, 100)
googlenet.cuda()
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=GoogLeNet_Weights.IMAGENET1K_V1`. You can also use `weights=GoogLeNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# GoogLeNet(
#   (conv1): BasicConv2d(
#     (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (conv2): BasicConv2d(
#     (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): BasicConv2d(
#     (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception3a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception3b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception4a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(208, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4c): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4d): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4e): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception5a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception5b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(48, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (aux1): None
#   (aux2): None
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc): Linear(in_features=1024, out_features=100, bias=True)
# )

# %%
def train_model(model, criterion, optimizer, trainloader, epochs=10):
    model.train()
    for epoch in range(epochs):
        running_loss = 0.0
        for i, (inputs, labels) in enumerate(trainloader):
            inputs, labels = inputs.cuda(), labels.cuda()

            optimizer.zero_grad()

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            if i % 100 == 99:
                print(f'Epoch {epoch+1}, Batch {i+1}, Loss: {running_loss / 100:.3f}')
                running_loss = 0.0
    print('Finished Training')

criterion = nn.CrossEntropyLoss()

# %%
# For AlexNet
optimizer_alex = optim.SGD(alexnet.parameters(), lr=0.01, momentum=0.9)
train_model(alexnet, criterion, optimizer_alex, trainloader)
# Out:
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.008
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.008
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.008
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.008
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Epoch 1, Batch 100/782, Avg Loss: 4.605
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.008
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.008
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.009
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.005
# Gradient norm of first layer: 0.010
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.009
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.008
# Gradient norm of first layer: 0.009
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.008
# Gradient norm of first layer: 0.008
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.008
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.008
# Gradient norm of first layer: 0.008
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.008
# Gradient norm of first layer: 0.009
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.009
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.006
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.007
# Gradient norm of first layer: 0.007
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-5cbad7e89d82> in <cell line: 3>()
#       1 # For AlexNet
#       2 optimizer_alex = optim.SGD(alexnet.parameters(), lr=0.01, momentum=0.9)
# ----> 3 train_model(alexnet, criterion, optimizer_alex, trainloader)
#
# <ipython-input-11-cda6c826dab0> in train_model(model, criterion, optimizer, trainloader, epochs)
#      18             optimizer.step()  # Update the weights
#      19
# ---> 20             running_loss += loss.item()
#      21
#      22             # Print detailed batch status
#
# KeyboardInterrupt:

# %%
# For VGG16
optimizer_vgg = optim.SGD(vgg16.parameters(), lr=0.001, momentum=0.9)
train_model(vgg16, criterion, optimizer_vgg, trainloader)
# Out:
# Epoch 1, Batch 100, Loss: 4.432
# Epoch 1, Batch 200, Loss: 3.454
# Epoch 1, Batch 300, Loss: 2.932
# Epoch 1, Batch 400, Loss: 2.678
# Epoch 1, Batch 500, Loss: 2.575
# Epoch 1, Batch 600, Loss: 2.485
# Epoch 1, Batch 700, Loss: 2.406
# Epoch 2, Batch 100, Loss: 2.255
# Epoch 2, Batch 200, Loss: 2.219
# Epoch 2, Batch 300, Loss: 2.208
# Epoch 2, Batch 400, Loss: 2.171
# Epoch 2, Batch 500, Loss: 2.121
# Epoch 2, Batch 600, Loss: 2.130
# Epoch 2, Batch 700, Loss: 2.051
# Epoch 3, Batch 100, Loss: 1.973
# Epoch 3, Batch 200, Loss: 1.998
# Epoch 3, Batch 300, Loss: 1.936
# Epoch 3, Batch 400, Loss: 1.969
# Epoch 3, Batch 500, Loss: 1.979
# Epoch 3, Batch 600, Loss: 1.906
# Epoch 3, Batch 700, Loss: 1.954
# Epoch 4, Batch 100, Loss: 1.880
# Epoch 4, Batch 200, Loss: 1.867
# Epoch 4, Batch 300, Loss: 1.840
# Epoch 4, Batch 400, Loss: 1.837
# Epoch 4, Batch 500, Loss: 1.808
# Epoch 4, Batch 600, Loss: 1.806
# Epoch 4, Batch 700, Loss: 1.845
# Epoch 5, Batch 100, Loss: 1.793
# Epoch 5, Batch 200, Loss: 1.757
# Epoch 5, Batch 300, Loss: 1.745
# Epoch 5, Batch 400, Loss: 1.742
# Epoch 5, Batch 500, Loss: 1.740
# Epoch 5, Batch 600, Loss: 1.726
# Epoch 5, Batch 700, Loss: 1.744
# Epoch 6, Batch 100, Loss: 1.650
# Epoch 6, Batch 200, Loss: 1.644
# Epoch 6, Batch 300, Loss: 1.684
# Epoch 6, Batch 400, Loss: 1.671
# Epoch 6, Batch 500, Loss: 1.695
# Epoch 6, Batch 600, Loss: 1.683
# Epoch 6, Batch 700, Loss: 1.686
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-a69a67b5c5c9> in <cell line: 3>()
#       1 # For VGG16
#       2 optimizer_vgg = optim.SGD(vgg16.parameters(), lr=0.001, momentum=0.9)
# ----> 3 train_model(vgg16, criterion, optimizer_vgg, trainloader)
#
# <ipython-input-14-5b947581d6e5> in train_model(model, criterion, optimizer, trainloader, epochs)
#      13             optimizer.step()
#      14
# ---> 15             running_loss += loss.item()
#      16             if i % 100 == 99:
#      17                 print(f'Epoch {epoch+1}, Batch {i+1}, Loss: {running_loss / 100:.3f}')
#
# KeyboardInterrupt:

# %%
# For ResNet50
optimizer_resnet = optim.SGD(resnet50.parameters(), lr=0.001, momentum=0.9)
train_model(resnet50, criterion, optimizer_resnet, trainloader)
# Out:
# Epoch 1, Batch 100, Loss: 4.502
# Epoch 1, Batch 200, Loss: 4.058
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-b0f2eedbc988> in <cell line: 3>()
#       1 # For ResNet50
#       2 optimizer_resnet = optim.SGD(resnet50.parameters(), lr=0.001, momentum=0.9)
# ----> 3 train_model(resnet50, criterion, optimizer_resnet, trainloader)
#
# <ipython-input-10-5b947581d6e5> in train_model(model, criterion, optimizer, trainloader, epochs)
#      13             optimizer.step()
#      14
# ---> 15             running_loss += loss.item()
#      16             if i % 100 == 99:
#      17                 print(f'Epoch {epoch+1}, Batch {i+1}, Loss: {running_loss / 100:.3f}')
#
# KeyboardInterrupt:

# %%
# For GoogleNet
optimizer_google = optim.SGD(googlenet.parameters(), lr=0.001, momentum=0.9)
train_model(googlenet, criterion, optimizer_google, trainloader)

# %%
def evaluate_model(model, testloader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.cuda(), labels.cuda()
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    print(f'Accuracy of the network on the test images: {accuracy} %')
    return accuracy

evaluate_model(alexnet, testloader)
evaluate_model(vgg16, testloader)
evaluate_model(resnet50, testloader)
evaluate_model(googlenet, testloader)

# %%
torch.save(alexnet.state_dict(), 'alexnet_cifar100.pth')
torch.save(vgg16.state_dict(), 'vgg16_cifar100.pth')
torch.save(resnet50.state_dict(), 'resnet50_cifar100.pth')
torch.save(googlenet.state_dict(), 'googlenet_cifar100.pth')

# %%
### new part from the book

from torchvision import models

transfer_model = models.resnet50(pretrained=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
for name, param in transfer_model.named_parameters():
    print(f'Parameter Name: {name:30} | Shape: {str(param.shape):30} | Trainable: {param.requires_grad} | Number of Elements: {param.numel()}')
# Out:
# Parameter Name: conv1.weight                   | Shape: torch.Size([64, 3, 7, 7])      | Trainable: True | Number of Elements: 9408
# Parameter Name: bn1.weight                     | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: bn1.bias                       | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.0.conv1.weight          | Shape: torch.Size([64, 64, 1, 1])     | Trainable: True | Number of Elements: 4096
# Parameter Name: layer1.0.bn1.weight            | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.0.bn1.bias              | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.0.conv2.weight          | Shape: torch.Size([64, 64, 3, 3])     | Trainable: True | Number of Elements: 36864
# Parameter Name: layer1.0.bn2.weight            | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.0.bn2.bias              | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.0.conv3.weight          | Shape: torch.Size([256, 64, 1, 1])    | Trainable: True | Number of Elements: 16384
# Parameter Name: layer1.0.bn3.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer1.0.bn3.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer1.0.downsample.0.weight   | Shape: torch.Size([256, 64, 1, 1])    | Trainable: True | Number of Elements: 16384
# Parameter Name: layer1.0.downsample.1.weight   | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer1.0.downsample.1.bias     | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer1.1.conv1.weight          | Shape: torch.Size([64, 256, 1, 1])    | Trainable: True | Number of Elements: 16384
# Parameter Name: layer1.1.bn1.weight            | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.1.bn1.bias              | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.1.conv2.weight          | Shape: torch.Size([64, 64, 3, 3])     | Trainable: True | Number of Elements: 36864
# Parameter Name: layer1.1.bn2.weight            | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.1.bn2.bias              | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.1.conv3.weight          | Shape: torch.Size([256, 64, 1, 1])    | Trainable: True | Number of Elements: 16384
# Parameter Name: layer1.1.bn3.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer1.1.bn3.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer1.2.conv1.weight          | Shape: torch.Size([64, 256, 1, 1])    | Trainable: True | Number of Elements: 16384
# Parameter Name: layer1.2.bn1.weight            | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.2.bn1.bias              | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.2.conv2.weight          | Shape: torch.Size([64, 64, 3, 3])     | Trainable: True | Number of Elements: 36864
# Parameter Name: layer1.2.bn2.weight            | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.2.bn2.bias              | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.2.conv3.weight          | Shape: torch.Size([256, 64, 1, 1])    | Trainable: True | Number of Elements: 16384
# Parameter Name: layer1.2.bn3.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer1.2.bn3.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer2.0.conv1.weight          | Shape: torch.Size([128, 256, 1, 1])   | Trainable: True | Number of Elements: 32768
# Parameter Name: layer2.0.bn1.weight            | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.0.bn1.bias              | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.0.conv2.weight          | Shape: torch.Size([128, 128, 3, 3])   | Trainable: True | Number of Elements: 147456
# Parameter Name: layer2.0.bn2.weight            | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.0.bn2.bias              | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.0.conv3.weight          | Shape: torch.Size([512, 128, 1, 1])   | Trainable: True | Number of Elements: 65536
# Parameter Name: layer2.0.bn3.weight            | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer2.0.bn3.bias              | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer2.0.downsample.0.weight   | Shape: torch.Size([512, 256, 1, 1])   | Trainable: True | Number of Elements: 131072
# Parameter Name: layer2.0.downsample.1.weight   | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer2.0.downsample.1.bias     | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer2.1.conv1.weight          | Shape: torch.Size([128, 512, 1, 1])   | Trainable: True | Number of Elements: 65536
# Parameter Name: layer2.1.bn1.weight            | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.1.bn1.bias              | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.1.conv2.weight          | Shape: torch.Size([128, 128, 3, 3])   | Trainable: True | Number of Elements: 147456
# Parameter Name: layer2.1.bn2.weight            | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.1.bn2.bias              | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.1.conv3.weight          | Shape: torch.Size([512, 128, 1, 1])   | Trainable: True | Number of Elements: 65536
# Parameter Name: layer2.1.bn3.weight            | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer2.1.bn3.bias              | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer2.2.conv1.weight          | Shape: torch.Size([128, 512, 1, 1])   | Trainable: True | Number of Elements: 65536
# Parameter Name: layer2.2.bn1.weight            | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.2.bn1.bias              | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.2.conv2.weight          | Shape: torch.Size([128, 128, 3, 3])   | Trainable: True | Number of Elements: 147456
# Parameter Name: layer2.2.bn2.weight            | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.2.bn2.bias              | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.2.conv3.weight          | Shape: torch.Size([512, 128, 1, 1])   | Trainable: True | Number of Elements: 65536
# Parameter Name: layer2.2.bn3.weight            | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer2.2.bn3.bias              | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer2.3.conv1.weight          | Shape: torch.Size([128, 512, 1, 1])   | Trainable: True | Number of Elements: 65536
# Parameter Name: layer2.3.bn1.weight            | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.3.bn1.bias              | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.3.conv2.weight          | Shape: torch.Size([128, 128, 3, 3])   | Trainable: True | Number of Elements: 147456
# Parameter Name: layer2.3.bn2.weight            | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.3.bn2.bias              | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.3.conv3.weight          | Shape: torch.Size([512, 128, 1, 1])   | Trainable: True | Number of Elements: 65536
# Parameter Name: layer2.3.bn3.weight            | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer2.3.bn3.bias              | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer3.0.conv1.weight          | Shape: torch.Size([256, 512, 1, 1])   | Trainable: True | Number of Elements: 131072
# Parameter Name: layer3.0.bn1.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.0.bn1.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.0.conv2.weight          | Shape: torch.Size([256, 256, 3, 3])   | Trainable: True | Number of Elements: 589824
# Parameter Name: layer3.0.bn2.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.0.bn2.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.0.conv3.weight          | Shape: torch.Size([1024, 256, 1, 1])  | Trainable: True | Number of Elements: 262144
# Parameter Name: layer3.0.bn3.weight            | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer3.0.bn3.bias              | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer3.0.downsample.0.weight   | Shape: torch.Size([1024, 512, 1, 1])  | Trainable: True | Number of Elements: 524288
# Parameter Name: layer3.0.downsample.1.weight   | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer3.0.downsample.1.bias     | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer3.1.conv1.weight          | Shape: torch.Size([256, 1024, 1, 1])  | Trainable: True | Number of Elements: 262144
# Parameter Name: layer3.1.bn1.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.1.bn1.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.1.conv2.weight          | Shape: torch.Size([256, 256, 3, 3])   | Trainable: True | Number of Elements: 589824
# Parameter Name: layer3.1.bn2.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.1.bn2.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.1.conv3.weight          | Shape: torch.Size([1024, 256, 1, 1])  | Trainable: True | Number of Elements: 262144
# Parameter Name: layer3.1.bn3.weight            | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer3.1.bn3.bias              | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer3.2.conv1.weight          | Shape: torch.Size([256, 1024, 1, 1])  | Trainable: True | Number of Elements: 262144
# Parameter Name: layer3.2.bn1.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.2.bn1.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.2.conv2.weight          | Shape: torch.Size([256, 256, 3, 3])   | Trainable: True | Number of Elements: 589824
# Parameter Name: layer3.2.bn2.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.2.bn2.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.2.conv3.weight          | Shape: torch.Size([1024, 256, 1, 1])  | Trainable: True | Number of Elements: 262144
# Parameter Name: layer3.2.bn3.weight            | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer3.2.bn3.bias              | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer3.3.conv1.weight          | Shape: torch.Size([256, 1024, 1, 1])  | Trainable: True | Number of Elements: 262144
# Parameter Name: layer3.3.bn1.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.3.bn1.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.3.conv2.weight          | Shape: torch.Size([256, 256, 3, 3])   | Trainable: True | Number of Elements: 589824
# Parameter Name: layer3.3.bn2.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.3.bn2.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.3.conv3.weight          | Shape: torch.Size([1024, 256, 1, 1])  | Trainable: True | Number of Elements: 262144
# Parameter Name: layer3.3.bn3.weight            | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer3.3.bn3.bias              | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer3.4.conv1.weight          | Shape: torch.Size([256, 1024, 1, 1])  | Trainable: True | Number of Elements: 262144
# Parameter Name: layer3.4.bn1.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.4.bn1.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.4.conv2.weight          | Shape: torch.Size([256, 256, 3, 3])   | Trainable: True | Number of Elements: 589824
# Parameter Name: layer3.4.bn2.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.4.bn2.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.4.conv3.weight          | Shape: torch.Size([1024, 256, 1, 1])  | Trainable: True | Number of Elements: 262144
# Parameter Name: layer3.4.bn3.weight            | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer3.4.bn3.bias              | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer3.5.conv1.weight          | Shape: torch.Size([256, 1024, 1, 1])  | Trainable: True | Number of Elements: 262144
# Parameter Name: layer3.5.bn1.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.5.bn1.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.5.conv2.weight          | Shape: torch.Size([256, 256, 3, 3])   | Trainable: True | Number of Elements: 589824
# Parameter Name: layer3.5.bn2.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.5.bn2.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.5.conv3.weight          | Shape: torch.Size([1024, 256, 1, 1])  | Trainable: True | Number of Elements: 262144
# Parameter Name: layer3.5.bn3.weight            | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer3.5.bn3.bias              | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer4.0.conv1.weight          | Shape: torch.Size([512, 1024, 1, 1])  | Trainable: True | Number of Elements: 524288
# Parameter Name: layer4.0.bn1.weight            | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer4.0.bn1.bias              | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer4.0.conv2.weight          | Shape: torch.Size([512, 512, 3, 3])   | Trainable: True | Number of Elements: 2359296
# Parameter Name: layer4.0.bn2.weight            | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer4.0.bn2.bias              | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer4.0.conv3.weight          | Shape: torch.Size([2048, 512, 1, 1])  | Trainable: True | Number of Elements: 1048576
# Parameter Name: layer4.0.bn3.weight            | Shape: torch.Size([2048])             | Trainable: True | Number of Elements: 2048
# Parameter Name: layer4.0.bn3.bias              | Shape: torch.Size([2048])             | Trainable: True | Number of Elements: 2048
# Parameter Name: layer4.0.downsample.0.weight   | Shape: torch.Size([2048, 1024, 1, 1]) | Trainable: True | Number of Elements: 2097152
# Parameter Name: layer4.0.downsample.1.weight   | Shape: torch.Size([2048])             | Trainable: True | Number of Elements: 2048
# Parameter Name: layer4.0.downsample.1.bias     | Shape: torch.Size([2048])             | Trainable: True | Number of Elements: 2048
# Parameter Name: layer4.1.conv1.weight          | Shape: torch.Size([512, 2048, 1, 1])  | Trainable: True | Number of Elements: 1048576
# Parameter Name: layer4.1.bn1.weight            | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer4.1.bn1.bias              | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer4.1.conv2.weight          | Shape: torch.Size([512, 512, 3, 3])   | Trainable: True | Number of Elements: 2359296
# Parameter Name: layer4.1.bn2.weight            | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer4.1.bn2.bias              | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer4.1.conv3.weight          | Shape: torch.Size([2048, 512, 1, 1])  | Trainable: True | Number of Elements: 1048576
# Parameter Name: layer4.1.bn3.weight            | Shape: torch.Size([2048])             | Trainable: True | Number of Elements: 2048
# Parameter Name: layer4.1.bn3.bias              | Shape: torch.Size([2048])             | Trainable: True | Number of Elements: 2048
# Parameter Name: layer4.2.conv1.weight          | Shape: torch.Size([512, 2048, 1, 1])  | Trainable: True | Number of Elements: 1048576
# Parameter Name: layer4.2.bn1.weight            | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer4.2.bn1.bias              | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer4.2.conv2.weight          | Shape: torch.Size([512, 512, 3, 3])   | Trainable: True | Number of Elements: 2359296
# Parameter Name: layer4.2.bn2.weight            | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer4.2.bn2.bias              | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer4.2.conv3.weight          | Shape: torch.Size([2048, 512, 1, 1])  | Trainable: True | Number of Elements: 1048576
# Parameter Name: layer4.2.bn3.weight            | Shape: torch.Size([2048])             | Trainable: True | Number of Elements: 2048
# Parameter Name: layer4.2.bn3.bias              | Shape: torch.Size([2048])             | Trainable: True | Number of Elements: 2048
# Parameter Name: fc.weight                      | Shape: torch.Size([1000, 2048])       | Trainable: True | Number of Elements: 2048000
# Parameter Name: fc.bias                        | Shape: torch.Size([1000])             | Trainable: True | Number of Elements: 1000

# %%
for name, param in transfer_model.named_parameters():
 if("bn" not in name):
  param.requires_grad = False

# %%
for name, param in transfer_model.named_parameters():
    print(f'Parameter Name: {name:30} | Shape: {str(param.shape):30} | Trainable: {param.requires_grad} | Number of Elements: {param.numel()}')
# Out:
# Parameter Name: conv1.weight                   | Shape: torch.Size([64, 3, 7, 7])      | Trainable: False | Number of Elements: 9408
# Parameter Name: bn1.weight                     | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: bn1.bias                       | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.0.conv1.weight          | Shape: torch.Size([64, 64, 1, 1])     | Trainable: False | Number of Elements: 4096
# Parameter Name: layer1.0.bn1.weight            | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.0.bn1.bias              | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.0.conv2.weight          | Shape: torch.Size([64, 64, 3, 3])     | Trainable: False | Number of Elements: 36864
# Parameter Name: layer1.0.bn2.weight            | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.0.bn2.bias              | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.0.conv3.weight          | Shape: torch.Size([256, 64, 1, 1])    | Trainable: False | Number of Elements: 16384
# Parameter Name: layer1.0.bn3.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer1.0.bn3.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer1.0.downsample.0.weight   | Shape: torch.Size([256, 64, 1, 1])    | Trainable: False | Number of Elements: 16384
# Parameter Name: layer1.0.downsample.1.weight   | Shape: torch.Size([256])              | Trainable: False | Number of Elements: 256
# Parameter Name: layer1.0.downsample.1.bias     | Shape: torch.Size([256])              | Trainable: False | Number of Elements: 256
# Parameter Name: layer1.1.conv1.weight          | Shape: torch.Size([64, 256, 1, 1])    | Trainable: False | Number of Elements: 16384
# Parameter Name: layer1.1.bn1.weight            | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.1.bn1.bias              | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.1.conv2.weight          | Shape: torch.Size([64, 64, 3, 3])     | Trainable: False | Number of Elements: 36864
# Parameter Name: layer1.1.bn2.weight            | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.1.bn2.bias              | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.1.conv3.weight          | Shape: torch.Size([256, 64, 1, 1])    | Trainable: False | Number of Elements: 16384
# Parameter Name: layer1.1.bn3.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer1.1.bn3.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer1.2.conv1.weight          | Shape: torch.Size([64, 256, 1, 1])    | Trainable: False | Number of Elements: 16384
# Parameter Name: layer1.2.bn1.weight            | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.2.bn1.bias              | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.2.conv2.weight          | Shape: torch.Size([64, 64, 3, 3])     | Trainable: False | Number of Elements: 36864
# Parameter Name: layer1.2.bn2.weight            | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.2.bn2.bias              | Shape: torch.Size([64])               | Trainable: True | Number of Elements: 64
# Parameter Name: layer1.2.conv3.weight          | Shape: torch.Size([256, 64, 1, 1])    | Trainable: False | Number of Elements: 16384
# Parameter Name: layer1.2.bn3.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer1.2.bn3.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer2.0.conv1.weight          | Shape: torch.Size([128, 256, 1, 1])   | Trainable: False | Number of Elements: 32768
# Parameter Name: layer2.0.bn1.weight            | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.0.bn1.bias              | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.0.conv2.weight          | Shape: torch.Size([128, 128, 3, 3])   | Trainable: False | Number of Elements: 147456
# Parameter Name: layer2.0.bn2.weight            | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.0.bn2.bias              | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.0.conv3.weight          | Shape: torch.Size([512, 128, 1, 1])   | Trainable: False | Number of Elements: 65536
# Parameter Name: layer2.0.bn3.weight            | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer2.0.bn3.bias              | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer2.0.downsample.0.weight   | Shape: torch.Size([512, 256, 1, 1])   | Trainable: False | Number of Elements: 131072
# Parameter Name: layer2.0.downsample.1.weight   | Shape: torch.Size([512])              | Trainable: False | Number of Elements: 512
# Parameter Name: layer2.0.downsample.1.bias     | Shape: torch.Size([512])              | Trainable: False | Number of Elements: 512
# Parameter Name: layer2.1.conv1.weight          | Shape: torch.Size([128, 512, 1, 1])   | Trainable: False | Number of Elements: 65536
# Parameter Name: layer2.1.bn1.weight            | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.1.bn1.bias              | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.1.conv2.weight          | Shape: torch.Size([128, 128, 3, 3])   | Trainable: False | Number of Elements: 147456
# Parameter Name: layer2.1.bn2.weight            | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.1.bn2.bias              | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.1.conv3.weight          | Shape: torch.Size([512, 128, 1, 1])   | Trainable: False | Number of Elements: 65536
# Parameter Name: layer2.1.bn3.weight            | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer2.1.bn3.bias              | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer2.2.conv1.weight          | Shape: torch.Size([128, 512, 1, 1])   | Trainable: False | Number of Elements: 65536
# Parameter Name: layer2.2.bn1.weight            | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.2.bn1.bias              | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.2.conv2.weight          | Shape: torch.Size([128, 128, 3, 3])   | Trainable: False | Number of Elements: 147456
# Parameter Name: layer2.2.bn2.weight            | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.2.bn2.bias              | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.2.conv3.weight          | Shape: torch.Size([512, 128, 1, 1])   | Trainable: False | Number of Elements: 65536
# Parameter Name: layer2.2.bn3.weight            | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer2.2.bn3.bias              | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer2.3.conv1.weight          | Shape: torch.Size([128, 512, 1, 1])   | Trainable: False | Number of Elements: 65536
# Parameter Name: layer2.3.bn1.weight            | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.3.bn1.bias              | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.3.conv2.weight          | Shape: torch.Size([128, 128, 3, 3])   | Trainable: False | Number of Elements: 147456
# Parameter Name: layer2.3.bn2.weight            | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.3.bn2.bias              | Shape: torch.Size([128])              | Trainable: True | Number of Elements: 128
# Parameter Name: layer2.3.conv3.weight          | Shape: torch.Size([512, 128, 1, 1])   | Trainable: False | Number of Elements: 65536
# Parameter Name: layer2.3.bn3.weight            | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer2.3.bn3.bias              | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer3.0.conv1.weight          | Shape: torch.Size([256, 512, 1, 1])   | Trainable: False | Number of Elements: 131072
# Parameter Name: layer3.0.bn1.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.0.bn1.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.0.conv2.weight          | Shape: torch.Size([256, 256, 3, 3])   | Trainable: False | Number of Elements: 589824
# Parameter Name: layer3.0.bn2.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.0.bn2.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.0.conv3.weight          | Shape: torch.Size([1024, 256, 1, 1])  | Trainable: False | Number of Elements: 262144
# Parameter Name: layer3.0.bn3.weight            | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer3.0.bn3.bias              | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer3.0.downsample.0.weight   | Shape: torch.Size([1024, 512, 1, 1])  | Trainable: False | Number of Elements: 524288
# Parameter Name: layer3.0.downsample.1.weight   | Shape: torch.Size([1024])             | Trainable: False | Number of Elements: 1024
# Parameter Name: layer3.0.downsample.1.bias     | Shape: torch.Size([1024])             | Trainable: False | Number of Elements: 1024
# Parameter Name: layer3.1.conv1.weight          | Shape: torch.Size([256, 1024, 1, 1])  | Trainable: False | Number of Elements: 262144
# Parameter Name: layer3.1.bn1.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.1.bn1.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.1.conv2.weight          | Shape: torch.Size([256, 256, 3, 3])   | Trainable: False | Number of Elements: 589824
# Parameter Name: layer3.1.bn2.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.1.bn2.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.1.conv3.weight          | Shape: torch.Size([1024, 256, 1, 1])  | Trainable: False | Number of Elements: 262144
# Parameter Name: layer3.1.bn3.weight            | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer3.1.bn3.bias              | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer3.2.conv1.weight          | Shape: torch.Size([256, 1024, 1, 1])  | Trainable: False | Number of Elements: 262144
# Parameter Name: layer3.2.bn1.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.2.bn1.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.2.conv2.weight          | Shape: torch.Size([256, 256, 3, 3])   | Trainable: False | Number of Elements: 589824
# Parameter Name: layer3.2.bn2.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.2.bn2.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.2.conv3.weight          | Shape: torch.Size([1024, 256, 1, 1])  | Trainable: False | Number of Elements: 262144
# Parameter Name: layer3.2.bn3.weight            | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer3.2.bn3.bias              | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer3.3.conv1.weight          | Shape: torch.Size([256, 1024, 1, 1])  | Trainable: False | Number of Elements: 262144
# Parameter Name: layer3.3.bn1.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.3.bn1.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.3.conv2.weight          | Shape: torch.Size([256, 256, 3, 3])   | Trainable: False | Number of Elements: 589824
# Parameter Name: layer3.3.bn2.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.3.bn2.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.3.conv3.weight          | Shape: torch.Size([1024, 256, 1, 1])  | Trainable: False | Number of Elements: 262144
# Parameter Name: layer3.3.bn3.weight            | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer3.3.bn3.bias              | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer3.4.conv1.weight          | Shape: torch.Size([256, 1024, 1, 1])  | Trainable: False | Number of Elements: 262144
# Parameter Name: layer3.4.bn1.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.4.bn1.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.4.conv2.weight          | Shape: torch.Size([256, 256, 3, 3])   | Trainable: False | Number of Elements: 589824
# Parameter Name: layer3.4.bn2.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.4.bn2.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.4.conv3.weight          | Shape: torch.Size([1024, 256, 1, 1])  | Trainable: False | Number of Elements: 262144
# Parameter Name: layer3.4.bn3.weight            | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer3.4.bn3.bias              | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer3.5.conv1.weight          | Shape: torch.Size([256, 1024, 1, 1])  | Trainable: False | Number of Elements: 262144
# Parameter Name: layer3.5.bn1.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.5.bn1.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.5.conv2.weight          | Shape: torch.Size([256, 256, 3, 3])   | Trainable: False | Number of Elements: 589824
# Parameter Name: layer3.5.bn2.weight            | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.5.bn2.bias              | Shape: torch.Size([256])              | Trainable: True | Number of Elements: 256
# Parameter Name: layer3.5.conv3.weight          | Shape: torch.Size([1024, 256, 1, 1])  | Trainable: False | Number of Elements: 262144
# Parameter Name: layer3.5.bn3.weight            | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer3.5.bn3.bias              | Shape: torch.Size([1024])             | Trainable: True | Number of Elements: 1024
# Parameter Name: layer4.0.conv1.weight          | Shape: torch.Size([512, 1024, 1, 1])  | Trainable: False | Number of Elements: 524288
# Parameter Name: layer4.0.bn1.weight            | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer4.0.bn1.bias              | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer4.0.conv2.weight          | Shape: torch.Size([512, 512, 3, 3])   | Trainable: False | Number of Elements: 2359296
# Parameter Name: layer4.0.bn2.weight            | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer4.0.bn2.bias              | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer4.0.conv3.weight          | Shape: torch.Size([2048, 512, 1, 1])  | Trainable: False | Number of Elements: 1048576
# Parameter Name: layer4.0.bn3.weight            | Shape: torch.Size([2048])             | Trainable: True | Number of Elements: 2048
# Parameter Name: layer4.0.bn3.bias              | Shape: torch.Size([2048])             | Trainable: True | Number of Elements: 2048
# Parameter Name: layer4.0.downsample.0.weight   | Shape: torch.Size([2048, 1024, 1, 1]) | Trainable: False | Number of Elements: 2097152
# Parameter Name: layer4.0.downsample.1.weight   | Shape: torch.Size([2048])             | Trainable: False | Number of Elements: 2048
# Parameter Name: layer4.0.downsample.1.bias     | Shape: torch.Size([2048])             | Trainable: False | Number of Elements: 2048
# Parameter Name: layer4.1.conv1.weight          | Shape: torch.Size([512, 2048, 1, 1])  | Trainable: False | Number of Elements: 1048576
# Parameter Name: layer4.1.bn1.weight            | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer4.1.bn1.bias              | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer4.1.conv2.weight          | Shape: torch.Size([512, 512, 3, 3])   | Trainable: False | Number of Elements: 2359296
# Parameter Name: layer4.1.bn2.weight            | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer4.1.bn2.bias              | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer4.1.conv3.weight          | Shape: torch.Size([2048, 512, 1, 1])  | Trainable: False | Number of Elements: 1048576
# Parameter Name: layer4.1.bn3.weight            | Shape: torch.Size([2048])             | Trainable: True | Number of Elements: 2048
# Parameter Name: layer4.1.bn3.bias              | Shape: torch.Size([2048])             | Trainable: True | Number of Elements: 2048
# Parameter Name: layer4.2.conv1.weight          | Shape: torch.Size([512, 2048, 1, 1])  | Trainable: False | Number of Elements: 1048576
# Parameter Name: layer4.2.bn1.weight            | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer4.2.bn1.bias              | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer4.2.conv2.weight          | Shape: torch.Size([512, 512, 3, 3])   | Trainable: False | Number of Elements: 2359296
# Parameter Name: layer4.2.bn2.weight            | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer4.2.bn2.bias              | Shape: torch.Size([512])              | Trainable: True | Number of Elements: 512
# Parameter Name: layer4.2.conv3.weight          | Shape: torch.Size([2048, 512, 1, 1])  | Trainable: False | Number of Elements: 1048576
# Parameter Name: layer4.2.bn3.weight            | Shape: torch.Size([2048])             | Trainable: True | Number of Elements: 2048
# Parameter Name: layer4.2.bn3.bias              | Shape: torch.Size([2048])             | Trainable: True | Number of Elements: 2048
# Parameter Name: fc.weight                      | Shape: torch.Size([1000, 2048])       | Trainable: False | Number of Elements: 2048000
# Parameter Name: fc.bias                        | Shape: torch.Size([1000])             | Trainable: False | Number of Elements: 1000

# %%
transfer_model.fc = nn.Sequential(nn.Linear(transfer_model.fc.in_features, 500),
                                  nn.ReLU(),
                                  nn.Dropout(),
                                  nn.Linear(500, 2))

# %%
import torch.optim as optimizer

optimizer = optimizer.Adam([
{ 'params': transfer_model.layer4.parameters(), 'lr': found_lr /3},
{ 'params': transfer_model.layer3.parameters(), 'lr': found_lr /9},
], lr=found_lr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-92e9d2c95787> in <cell line: 3>()
#       2
#       3 optimizer = optimizer.Adam([
# ----> 4 { 'params': transfer_model.layer4.parameters(), 'lr': found_lr /3},
#       5 { 'params': transfer_model.layer3.parameters(), 'lr': found_lr /9},
#       6 ], lr=found_lr)
#
# NameError: name 'found_lr' is not defined
